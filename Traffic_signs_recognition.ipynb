# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
  print('and then re-execute this cell.')
else:
  print(gpu_info)
# Out:
# Wed Jun 22 03:06:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/YOLO'
# Out:
# /content/drive/MyDrive/Colab Notebooks/YOLO

# %%
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/YOLO/train_data.zip" -d "/content/drive/MyDrive/Colab Notebooks/YOLO"

# %%
# !unzip -q "/content/drive/MyDrive/Colab Notebooks/YOLO/test_data.zip" -d "/content/drive/MyDrive/Colab Notebooks/YOLO"

# %%
#!git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.11.0+cu113 (Tesla T4)

# %% [markdown]
# Train model with YOLOv5s

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/train.py" --img 640 --batch 32 --epochs 500 --data "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml" --weights "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/yolov5s.pt" --cache
# Out:
# train: weights=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/yolov5s.pt, cfg=, data=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=500, batch_size=32, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %% [markdown]
# Continue training

# %%
# !python train.py --resume "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt"
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# Resuming training from /content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# ...

# %%
# !python train.py --resume "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt"
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/coco128.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=640, rect=False, resume=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 82 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# Resuming training from /content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/last.pt
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# ...

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/val.py' --weights '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt' --data '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml'
# Out:
# val: data=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml, weights=['/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7042489 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/../train_data/labels/val.cache' images and labels... 279 found, 0 missing, 0 empty, 0 corrupt: 100% 279/279 [00:00<?, ?it/s]
# ...

# %%
# Run YOLOv5x on COCO val
# !python '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/val.py' --weights '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt' --data '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml' --img 640 --iou 0.65 --half
# Out:
# val: data=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml, weights=['/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7042489 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/../train_data/labels/val.cache' images and labels... 279 found, 0 missing, 0 empty, 0 corrupt: 100% 279/279 [00:00<?, ?it/s]
# ...

# %%
# Run YOLOv5x on COCO val
# !python '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/val.py' --weights '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt' --data '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml' --img 640 --iou 0.65 --half --task test
# Out:
# val: data=/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml, weights=['/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.65, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7042489 parameters, 0 gradients
# test: Scanning '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/../test_data/labels' images and labels...282 found, 0 missing, 0 empty, 0 corrupt: 100% 282/282 [00:52<00:00,  5.41it/s]
# test: New cache created: /content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/../test_data/labels.cache
# ...

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/detect.py' --weights '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt' --img 640 --conf 0.3 --source '/content/drive/MyDrive/Colab Notebooks/YOLO/test_data/images'
# Out:
# detect: weights=['/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp11/weights/best.pt'], source=/content/drive/MyDrive/Colab Notebooks/YOLO/test_data/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.3, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7042489 parameters, 0 gradients
# image 1/282 /content/drive/MyDrive/Colab Notebooks/YOLO/test_data/images/IMG1--100-_jpg.rf.722e9bfcff5af4199502c1d8513f88f9.jpg: 640x640 1 CamDiNguocChieu, Done. (0.013s)
# ...

# %%
# !python '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/detect.py' --weights '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp10/weights/best.pt' --img 640 --conf 0.5 --source '/content/drive/MyDrive/Colab Notebooks/YOLO/test_data/images'
# Out:
# python3: can't open file '/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/detect.py': [Errno 2] No such file or directory

# %%
# !python "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/export.py" --weights "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp10/weights/best.pt" --include onnx
# Out:
# export: data=data/coco128.yaml, weights=['/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp10/weights/best.pt'], imgsz=[640, 640], batch_size=1, device=cpu, half=False, inplace=False, train=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=12, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['onnx']
# fatal: cannot change to '/content/drive/MyDrive/Colab': No such file or directory
# YOLOv5 🚀 2022-5-6 torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7064065 parameters, 0 gradients, 16.0 GFLOPs
#
# PyTorch: starting from /content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp10/weights/best.pt with output shape (1, 25200, 25) (13.9 MB)
# requirements: onnx not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# ...

# %%
# Continues training 
# !python "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/train.py" --img 640 --batch 32 --epochs 500 --data "/content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/data/custom_data.yaml" --weights /content/drive/MyDrive/Colab Notebooks/YOLO/yolov5/runs/train/exp9/weights/last.pt --cache

# %%
dd
